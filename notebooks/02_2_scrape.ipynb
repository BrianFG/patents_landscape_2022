# %% [markdown]
# Import the required libraries

# %% [markdown]
# Lets read the CSV file that we saved before
#
#  Using `read_csv()`

# %% [markdown]
# Get the first 3 elements of that table

# %% [markdown]
# ### Getting one url to analyze

# %% [markdown]
# ![patents1.png](attachment:583e2056-b153-4d8c-b501-1f71c7547380.png)

# %% [markdown]
# Lets assign this to a variable for easier use

# %% [markdown]
# Using library `request` we can get the `HTML` content

# %% [markdown]
# Status code tells you if the requests was successful, 200 code is OK

# %% [markdown]
# We will use Library `Beautiful Soup` to parse the HTML document

# %% [markdown]
# Lets find how we can get the abstract
#
# A good tip would be searching for the words that you want

# %% [markdown]
# ![patents2.png](attachment:a27c382e-14d1-461d-96e7-08eff97ba86b.png)

# %% [markdown]
# Notice there are 3 possible ways to obtain the information
#
# - 2 `<meta>` tags
# - 1 inside a `<section>` tag

# %% [markdown]
# Lets get the one inside the section, using function for BeautifulSoup called `select`

# %% [markdown]
# ---

# %% [markdown]
# ## Scraping the document

# %% [markdown]
# first we will be converting the `DataFrame` into a list of `JSON` files

# %% [markdown]
# Lets see if our class works
#
# Use the first element of the list

# %% [markdown]
# Lets check the fields

# %% [markdown]
# We will define a function to scrape a document

# %% [markdown]
# Since we will be scrapping many documents, a good practice is to use parallel programming

# %% [markdown]
# Check if the documents were parsed correctly

# %% [markdown]
# ---
#
# ## Saving the JSON to Local Storage

# %%
import json

# %% [markdown]
# Save the document locally
